# %% [markdown]
# <a href="https://colab.research.google.com/github/ab-rohman/Computer_Vision/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
#Step 2 (face det)
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')

# Presiden Face
presiden = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/jokowi.jpg')
presiden1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/jokowi.jpg')
roi_wajah1 = face_cascade.detectMultiScale(presiden1) 

roi_face = face_cascade.detectMultiScale(presiden) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(presiden,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(presiden1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(presiden1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(presiden, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(presiden, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Step 2 (face det)
# Ibu Kartini Face
ibu_kartini = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/kartini.jpg')
ibu_kartini1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/kartini.jpg')
roi_wajah1 = face_cascade.detectMultiScale(ibu_kartini1) 

roi_face = face_cascade.detectMultiScale(ibu_kartini) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(ibu_kartini,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(ibu_kartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(ibu_kartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(ibu_kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(ibu_kartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Step 2 (face det)
# Cat Face
cat = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/kucing.jpg')
cat1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/kucing.jpg')
roi_wajah1 = face_cascade.detectMultiScale(cat1) 

roi_face = face_cascade.detectMultiScale(cat) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(cat,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(cat1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(cat1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(cat, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(cat, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Step 2 (face det)
# Masked Face
masked = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/mask.png',0)
masked1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/mask.png',0)
roi_wajah1 = face_cascade.detectMultiScale(masked1) 

roi_face = face_cascade.detectMultiScale(masked) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(masked,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(masked1, cmap='gray')
plt.subplot(122),plt.imshow(masked, cmap='gray')
plt.show()

# %%
# unMask Face Detection
unMask = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/mjordan.jpg', 0)
unMask1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/mjordan.jpg', 0)

roi_wajah = face_cascade.detectMultiScale(unMask1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(unMask1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(5,5))
plt.subplot(121),plt.imshow(unMask, cmap='gray')
plt.subplot(122),plt.imshow(unMask1, cmap='gray')
plt.show()

# %%
# group of people
group = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/solvayconf.jpg', 0)
group1 = cv.imread('/content/drive/MyDrive/Colab Notebooks/Images_PCVK/Images/facedet/solvayconf.jpg', 0)

roi_wajah = face_cascade.detectMultiScale(group1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(group1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(group, cmap='gray')
plt.subplot(122),plt.imshow(group1, cmap='gray')
plt.show()
